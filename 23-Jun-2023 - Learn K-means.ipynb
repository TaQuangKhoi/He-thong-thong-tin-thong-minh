# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
means = [
    [2, 2],
    [3, 7],
    [7, 3],
    [8, 8]
]

covariances = [
    [1, 0],
    [0, 1]
]

N = 500

print(means)
print(covariances)
print(N)
# Out:
# [[2, 2], [3, 7], [7, 3], [8, 8]]
# [[1, 0], [0, 1]]
# 500

# %% [markdown]
# # Tạo class 0 bằng random

# %%
class0 = np.random.multivariate_normal(means[0], covariances, 100)
class0
# Out:
# array([[ 2.00033788,  2.64348313],
#        [ 2.21932243,  1.26609526],
#        [ 3.57788139,  2.27654974],
#        [ 2.98248908,  2.76667051],
#        [ 3.27481183,  1.65916632],
#        [ 3.5626262 ,  3.51814995],
#        [ 1.36530464,  3.06877551],
#        [ 2.90230483,  3.46303106],
#        [ 1.07159282,  0.91784669],
#        [ 1.60199904,  1.63681163],
#        [ 1.81322253,  2.93991555],
#        [ 2.02215994,  1.82024586],
#        [ 1.11087757,  3.79984871],
#        [ 1.58635769,  2.06491206],
#        [ 1.55295825,  2.04149114],
#        [ 1.83549487,  2.41953933],
#        [ 1.90505816,  1.33242058],
#        [ 1.42023104,  2.40158742],
#        [ 0.78345302,  3.04359368],
#        [ 3.51429044,  3.45441446],
#        [ 1.39002623,  1.50795575],
#        [ 0.77614063,  2.3927889 ],
#        [ 1.31564622,  3.51371321],
#        [ 1.91854409,  0.63877537],
#        [ 1.3541775 ,  2.69322165],
#        [ 0.38404707,  1.5652718 ],
#        [ 2.90538288,  1.37898441],
# ...
